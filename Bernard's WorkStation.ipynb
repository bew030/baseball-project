# %%
# imports

import json
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
import warnings
pd.options.mode.chained_assignment = None
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Reading in the Data

# %% [markdown]
# Before we can do any data analysis, we need to be able to actually find and read in data. After doing some research, we found a website that basically had an archive for data for multiple sports (including baseball). Because we couldn't just download the datasets and because we didn't want to manually type out the datapoints, we decided to utilize web scraping to read in the data for us.
#
# The first step was to come up with all the links that we were planning to scrape. Because the first page of the search result contained hyperlinks to all the other pages of the search result, we scraped the first page for all the HTMLs and then created a list of URLs to scrape.

# %%
# base link used for each page 
base_link = 'https://www.prosportstransactions.com/baseball/Search/' 
# link to the first page of the search result 
link = 'https://www.prosportstransactions.com/baseball/Search/SearchResults.php?Player=&Team=&BeginDate=2000-01-01&EndDate=2019-11-19&DLChkBx=yes&submit=Search'

# %%
r = requests.get(link)
urlText = r.text

# %%
soup = BeautifulSoup(urlText, 'html.parser') # reads everything into something more readable than HTML

# %%
all_links  = soup.find_all('a') # finds all links within the page

# %%
# removes first and last 4 links, which are extraneous links
important_links = [x.get('href') for x in all_links[4:-4]] 

# adds base URL to each link to make each link a proper URL link for each page 
final_links = [link]
final_links = final_links+[base_link+x for x in important_links]

# %%
len(final_links)
# Out:
# 855

# %% [markdown]
# final_links contains the final list of all the URLs we're planning to scrape. We can then create a method that will loop through the links and properly scrape the data and concatenate it onto a dataframe. This method is timed and only used once: delays are set so that the website isn’t overloaded with traffic, and once the method runs through once the dataset gets saved as a csv to ensure that the website isn’t abused.

# %%
def number_cycles(links, n=3,sleep_time=2):
    '''
    This method takes in a list of links and scrapes the data, neatly organizing it into a dataframe. 
    Parameters: 
        Links: the list of URL links that you want to scrape 
        n: the number of links you want to read in from the list, default 3 
        sleep_time: the time the loop waits before reading in the website, default 2 seconds, TIME SHOULD BE INCREASED
            IF LENGTH OF LIST OF URLS IS LARGE
    Returns: 
        returns the dataframe containing the data scraped from all the links from the inputted list 
    '''
    final_df = pd.DataFrame()
    for i in range(n):
        print('working on page '+str(i))
        sleep(sleep_time)
        test = pd.read_html(links[i],header = 0)[0]
        final_df = pd.concat([final_df, test],ignore_index = True)
    return final_df

# %%
df = number_cycles(final_links,len(final_links),sleep_time=0)
# Out:
# working on page 0
# working on page 1
# working on page 2
# working on page 3
# working on page 4
# working on page 5
# working on page 6
# working on page 7
# working on page 8
# working on page 9
# working on page 10
# working on page 11
# working on page 12
# working on page 13
# working on page 14
# working on page 15
# working on page 16
# working on page 17
# working on page 18
# working on page 19
# working on page 20
# working on page 21
# working on page 22
# working on page 23
# working on page 24
# working on page 25
# working on page 26
# working on page 27
# working on page 28
# working on page 29
# working on page 30
# working on page 31
# working on page 32
# working on page 33
# working on page 34
# working on page 35
# working on page 36
# working on page 37
# working on page 38
# working on page 39
# working on page 40
# working on page 41
# working on page 42
# working on page 43
# working on page 44
# working on page 45
# working on page 46
# working on page 47
# working on page 48
# working on page 49
# working on page 50
# working on page 51
# working on page 52
# working on page 53
# working on page 54
# working on page 55
# working on page 56
# working on page 57
# working on page 58
# working on page 59
# working on page 60
# working on page 61
# working on page 62
# working on page 63
# working on page 64
# working on page 65
# working on page 66
# working on page 67
# working on page 68
# working on page 69
# working on page 70
# working on page 71
# working on page 72
# working on page 73
# working on page 74
# working on page 75
# working on page 76
# working on page 77
# working on page 78
# working on page 79
# working on page 80
# working on page 81
# working on page 82
# working on page 83
# working on page 84
# working on page 85
# working on page 86
# working on page 87
# working on page 88
# working on page 89
# working on page 90
# working on page 91
# working on page 92
# working on page 93
# working on page 94
# working on page 95
# working on page 96
# working on page 97
# working on page 98
# working on page 99
# working on page 100
# working on page 101
# working on page 102
# working on page 103
# working on page 104
# working on page 105
# working on page 106
# working on page 107
# working on page 108
# working on page 109
# working on page 110
# working on page 111
# working on page 112
# working on page 113
# working on page 114
# working on page 115
# working on page 116
# working on page 117
# working on page 118
# working on page 119
# working on page 120
# working on page 121
# working on page 122
# working on page 123
# working on page 124
# working on page 125
# working on page 126
# working on page 127
# working on page 128
# working on page 129
# working on page 130
# working on page 131
# working on page 132
# working on page 133
# working on page 134
# working on page 135
# working on page 136
# working on page 137
# working on page 138
# working on page 139
# working on page 140
# working on page 141
# working on page 142
# working on page 143
# working on page 144
# working on page 145
# working on page 146
# working on page 147
# working on page 148
# working on page 149
# working on page 150
# working on page 151
# working on page 152
# working on page 153
# working on page 154
# working on page 155
# working on page 156
# working on page 157
# working on page 158
# working on page 159
# working on page 160
# working on page 161
# working on page 162
# working on page 163
# working on page 164
# working on page 165
# working on page 166
# working on page 167
# working on page 168
# working on page 169
# working on page 170
# working on page 171
# working on page 172
# working on page 173
# working on page 174
# working on page 175
# working on page 176
# working on page 177
# working on page 178
# working on page 179
# working on page 180
# working on page 181
# working on page 182
# working on page 183
# working on page 184
# working on page 185
# working on page 186
# working on page 187
# working on page 188
# working on page 189
# working on page 190
# working on page 191
# working on page 192
# working on page 193
# working on page 194
# working on page 195
# working on page 196
# working on page 197
# working on page 198
# working on page 199
# working on page 200
# working on page 201
# working on page 202
# working on page 203
# working on page 204
# working on page 205
# working on page 206
# working on page 207
# working on page 208
# working on page 209
# working on page 210
# working on page 211
# working on page 212
# working on page 213
# working on page 214
# working on page 215
# working on page 216
# working on page 217
# working on page 218
# working on page 219
# working on page 220
# working on page 221
# working on page 222
# working on page 223
# working on page 224
# working on page 225
# working on page 226
# working on page 227
# working on page 228
# working on page 229
# working on page 230
# working on page 231
# working on page 232
# working on page 233
# working on page 234
# working on page 235
# working on page 236
# working on page 237
# working on page 238
# working on page 239
# working on page 240
# working on page 241
# working on page 242
# working on page 243
# working on page 244
# working on page 245
# working on page 246
# working on page 247
# working on page 248
# working on page 249
# working on page 250
# working on page 251
# working on page 252
# working on page 253
# working on page 254
# working on page 255
# working on page 256
# working on page 257
# working on page 258
# working on page 259
# working on page 260
# working on page 261
# working on page 262
# working on page 263
# working on page 264
# working on page 265
# working on page 266
# working on page 267
# working on page 268
# working on page 269
# working on page 270
# working on page 271
# working on page 272
# working on page 273
# working on page 274
# working on page 275
# working on page 276
# working on page 277
# working on page 278
# working on page 279
# working on page 280
# working on page 281
# working on page 282
# working on page 283
# working on page 284
# working on page 285
# working on page 286
# working on page 287
# working on page 288
# working on page 289
# working on page 290
# working on page 291
# working on page 292
# working on page 293
# working on page 294
# working on page 295
# working on page 296
# working on page 297
# working on page 298
# working on page 299
# working on page 300
# working on page 301
# working on page 302
# working on page 303
# working on page 304
# working on page 305
# working on page 306
# working on page 307
# working on page 308
# working on page 309
# working on page 310
# working on page 311
# working on page 312
# working on page 313
# working on page 314
# working on page 315
# working on page 316
# working on page 317
# working on page 318
# working on page 319
# working on page 320
# working on page 321
# working on page 322
# working on page 323
# working on page 324
# working on page 325
# working on page 326
# working on page 327
# working on page 328
# working on page 329
# working on page 330
# working on page 331
# working on page 332
# working on page 333
# working on page 334
# working on page 335
# working on page 336
# working on page 337
# working on page 338
# working on page 339
# working on page 340
# working on page 341
# working on page 342
# working on page 343
# working on page 344
# working on page 345
# working on page 346
# working on page 347
# working on page 348
# working on page 349
# working on page 350
# working on page 351
# working on page 352
# working on page 353
# working on page 354
# working on page 355
# working on page 356
# working on page 357
# working on page 358
# working on page 359
# working on page 360
# working on page 361
# working on page 362
# working on page 363
# working on page 364
# working on page 365
# working on page 366
# working on page 367
# working on page 368
# working on page 369
# working on page 370
# working on page 371
# working on page 372
# working on page 373
# working on page 374
# working on page 375
# working on page 376
# working on page 377
# working on page 378
# working on page 379
# working on page 380
# working on page 381
# working on page 382
# working on page 383
# working on page 384
# working on page 385
# working on page 386
# working on page 387
# working on page 388
# working on page 389
# working on page 390
# working on page 391
# working on page 392
# working on page 393
# working on page 394
# working on page 395
# working on page 396
# working on page 397
# working on page 398
# working on page 399
# working on page 400
# working on page 401
# working on page 402
# working on page 403
# working on page 404
# working on page 405
# working on page 406
# working on page 407
# working on page 408
# working on page 409
# working on page 410
# working on page 411
# working on page 412
# working on page 413
# working on page 414
# working on page 415
# working on page 416
# working on page 417
# working on page 418
# working on page 419
# working on page 420
# working on page 421
# working on page 422
# working on page 423
# working on page 424
# working on page 425
# working on page 426
# working on page 427
# working on page 428
# working on page 429
# working on page 430
# working on page 431
# working on page 432
# working on page 433
# working on page 434
# working on page 435
# working on page 436
# working on page 437
# working on page 438
# working on page 439
# working on page 440
# working on page 441
# working on page 442
# working on page 443
# working on page 444
# working on page 445
# working on page 446
# working on page 447
# working on page 448
# working on page 449
# working on page 450
# working on page 451
# working on page 452
# working on page 453
# working on page 454
# working on page 455
# working on page 456
# working on page 457
# working on page 458
# working on page 459
# working on page 460
# working on page 461
# working on page 462
# working on page 463
# working on page 464
# working on page 465
# working on page 466
# working on page 467
# working on page 468
# working on page 469
# working on page 470
# working on page 471
# working on page 472
# working on page 473
# working on page 474
# working on page 475
# working on page 476
# working on page 477
# working on page 478
# working on page 479
# working on page 480
# working on page 481
# working on page 482
# working on page 483
# working on page 484
# working on page 485
# working on page 486
# working on page 487
# working on page 488
# working on page 489
# working on page 490
# working on page 491
# working on page 492
# working on page 493
# working on page 494
# working on page 495
# working on page 496
# working on page 497
# working on page 498
# working on page 499
# working on page 500
# working on page 501
# working on page 502
# working on page 503
# working on page 504
# working on page 505
# working on page 506
# working on page 507
# working on page 508
# working on page 509
# working on page 510
# working on page 511
# working on page 512
# working on page 513
# working on page 514
# working on page 515
# working on page 516
# working on page 517
# working on page 518
# working on page 519
# working on page 520
# working on page 521
# working on page 522
# working on page 523
# working on page 524
# working on page 525
# working on page 526
# working on page 527
# working on page 528
# working on page 529
# working on page 530
# working on page 531
# working on page 532
# working on page 533
# working on page 534
# working on page 535
# working on page 536
# working on page 537
# working on page 538
# working on page 539
# working on page 540
# working on page 541
# working on page 542
# working on page 543
# working on page 544
# working on page 545
# working on page 546
# working on page 547
# working on page 548
# working on page 549
# working on page 550
# working on page 551
# working on page 552
# working on page 553
# working on page 554
# working on page 555
# working on page 556
# working on page 557
# working on page 558
# working on page 559
# working on page 560
# working on page 561
# working on page 562
# working on page 563
# working on page 564
# working on page 565
# working on page 566
# working on page 567
# working on page 568
# working on page 569
# working on page 570
# working on page 571
# working on page 572
# working on page 573
# working on page 574
# working on page 575
# working on page 576
# working on page 577
# working on page 578
# working on page 579
# working on page 580
# working on page 581
# working on page 582
# working on page 583
# working on page 584
# working on page 585
# working on page 586
# working on page 587
# working on page 588
# working on page 589
# working on page 590
# working on page 591
# working on page 592
# working on page 593
# working on page 594
# working on page 595
# working on page 596
# working on page 597
# working on page 598
# working on page 599
# working on page 600
# working on page 601
# working on page 602
# working on page 603
# working on page 604
# working on page 605
# working on page 606
# working on page 607
# working on page 608
# working on page 609
# working on page 610
# working on page 611
# working on page 612
# working on page 613
# working on page 614
# working on page 615
# working on page 616
# working on page 617
# working on page 618
# working on page 619
# working on page 620
# working on page 621
# working on page 622
# working on page 623
# working on page 624
# working on page 625
# working on page 626
# working on page 627
# working on page 628
# working on page 629
# working on page 630
# working on page 631
# working on page 632
# working on page 633
# working on page 634
# working on page 635
# working on page 636
# working on page 637
# working on page 638
# working on page 639
# working on page 640
# working on page 641
# working on page 642
# working on page 643
# working on page 644
# working on page 645
# working on page 646
# working on page 647
# working on page 648
# working on page 649
# working on page 650
# working on page 651
# working on page 652
# working on page 653
# working on page 654
# working on page 655
# working on page 656
# working on page 657
# working on page 658
# working on page 659
# working on page 660
# working on page 661
# working on page 662
# working on page 663
# working on page 664
# working on page 665
# working on page 666
# working on page 667
# working on page 668
# working on page 669
# working on page 670
# working on page 671
# working on page 672
# working on page 673
# working on page 674
# working on page 675
# working on page 676
# working on page 677
# working on page 678
# working on page 679
# working on page 680
# working on page 681
# working on page 682
# working on page 683
# working on page 684
# working on page 685
# working on page 686
# working on page 687
# working on page 688
# working on page 689
# working on page 690
# working on page 691
# working on page 692
# working on page 693
# working on page 694
# working on page 695
# working on page 696
# working on page 697
# working on page 698
# working on page 699
# working on page 700
# working on page 701
# working on page 702
# working on page 703
# working on page 704
# working on page 705
# working on page 706
# working on page 707
# working on page 708
# working on page 709
# working on page 710
# working on page 711
# working on page 712
# working on page 713
# working on page 714
# working on page 715
# working on page 716
# working on page 717
# working on page 718
# working on page 719
# working on page 720
# working on page 721
# working on page 722
# working on page 723
# working on page 724
# working on page 725
# working on page 726
# working on page 727
# working on page 728
# working on page 729
# working on page 730
# working on page 731
# working on page 732
# working on page 733
# working on page 734
# working on page 735
# working on page 736
# working on page 737
# working on page 738
# working on page 739
# working on page 740
# working on page 741
# working on page 742
# working on page 743
# working on page 744
# working on page 745
# working on page 746
# working on page 747
# working on page 748
# working on page 749
# working on page 750
# working on page 751
# working on page 752
# working on page 753
# working on page 754
# working on page 755
# working on page 756
# working on page 757
# working on page 758
# working on page 759
# working on page 760
# working on page 761
# working on page 762
# working on page 763
# working on page 764
# working on page 765
# working on page 766
# working on page 767
# working on page 768
# working on page 769
# working on page 770
# working on page 771
# working on page 772
# working on page 773
# working on page 774
# working on page 775
# working on page 776
# working on page 777
# working on page 778
# working on page 779
# working on page 780
# working on page 781
# working on page 782
# working on page 783
# working on page 784
# working on page 785
# working on page 786
# working on page 787
# working on page 788
# working on page 789
# working on page 790
# working on page 791
# working on page 792
# working on page 793
# working on page 794
# working on page 795
# working on page 796
# working on page 797
# working on page 798
# working on page 799
# working on page 800
# working on page 801
# working on page 802
# working on page 803
# working on page 804
# working on page 805
# working on page 806
# working on page 807
# working on page 808
# working on page 809
# working on page 810
# working on page 811
# working on page 812
# working on page 813
# working on page 814
# working on page 815
# working on page 816
# working on page 817
# working on page 818
# working on page 819
# working on page 820
# working on page 821
# working on page 822
# working on page 823
# working on page 824
# working on page 825
# working on page 826
# working on page 827
# working on page 828
# working on page 829
# working on page 830
# working on page 831
# working on page 832
# working on page 833
# working on page 834
# working on page 835
# working on page 836
# working on page 837
# working on page 838
# working on page 839
# working on page 840
# working on page 841
# working on page 842
# working on page 843
# working on page 844
# working on page 845
# working on page 846
# working on page 847
# working on page 848
# working on page 849
# working on page 850
# working on page 851
# working on page 852
# working on page 853
# working on page 854

# %%
df.to_csv('baseball_datasets/webscraped_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       Date        Team Acquired   Relinquished  \
# 0           0 2000-03-23     Rockies      NaN     hn Thomson
# 1           1 2000-04-01  Devil Rays      NaN   lson Alvarez
# 2           2 2000-04-01     Dodgers      NaN    tonio Osuna
# 3           3 2000-04-08        Mets      NaN  rryl Hamilton
# 4           4 2000-04-08     Orioles      NaN      ke Timlin
#
#                                                Notes
# 0  placed on 60-day DL recovering from surgery on...
# 1                                       placed on DL
# 2                                placed on 15-day DL
# 3        placed on 15-day DL with sprained left foot
# 4        placed on 15-day DL with strained abdominal

# %% [markdown]
# Now we have a dataset that we can use! We can begin to analyze and clean it.

# %% [markdown]
# # Understanding and Cleaning the Dataset

# %%
# reading in CSV 
df = pd.read_csv('baseball_datasets/webscraped_dataset.csv')

# %%
def dot_remover(x):
    if not (x == x):
        return x 
    else: 
        return x[2:]
    
def dot_cleaner(df):
    df['Acquired'] = df['Acquired'].apply(dot_remover)
    df['Relinquished'] = df['Relinquished'].apply(dot_remover)
    return df

# %%
no_dots_df = dot_cleaner(df)

# %%
no_dots_df.head()
# Out:
#    Unnamed: 0        Date        Team Acquired     Relinquished  \
# 0           0  2000-03-23     Rockies      NaN     John Thomson
# 1           1  2000-04-01  Devil Rays      NaN   Wilson Alvarez
# 2           2  2000-04-01     Dodgers      NaN    Antonio Osuna
# 3           3  2000-04-08        Mets      NaN  Darryl Hamilton
# 4           4  2000-04-08     Orioles      NaN      Mike Timlin
#
#                                                Notes
# 0  placed on 60-day DL recovering from surgery on...
# 1                                       placed on DL
# 2                                placed on 15-day DL
# 3        placed on 15-day DL with sprained left foot
# 4        placed on 15-day DL with strained abdominal

# %%
no_dots_df['Date'] = pd.to_datetime(no_dots_df['Date'])

# %%
no_dots_df.head()
# Out:
#    Unnamed: 0       Date        Team Acquired     Relinquished  \
# 0           0 2000-03-23     Rockies      NaN     John Thomson
# 1           1 2000-04-01  Devil Rays      NaN   Wilson Alvarez
# 2           2 2000-04-01     Dodgers      NaN    Antonio Osuna
# 3           3 2000-04-08        Mets      NaN  Darryl Hamilton
# 4           4 2000-04-08     Orioles      NaN      Mike Timlin
#
#                                                Notes
# 0  placed on 60-day DL recovering from surgery on...
# 1                                       placed on DL
# 2                                placed on 15-day DL
# 3        placed on 15-day DL with sprained left foot
# 4        placed on 15-day DL with strained abdominal

# %%
no_dots_df.head()
# Out:
#    Unnamed: 0       Date        Team Acquired     Relinquished  \
# 0           0 2000-03-23     Rockies      NaN     John Thomson
# 1           1 2000-04-01  Devil Rays      NaN   Wilson Alvarez
# 2           2 2000-04-01     Dodgers      NaN    Antonio Osuna
# 3           3 2000-04-08        Mets      NaN  Darryl Hamilton
# 4           4 2000-04-08     Orioles      NaN      Mike Timlin
#
#                                                Notes
# 0  placed on 60-day DL recovering from surgery on...
# 1                                       placed on DL
# 2                                placed on 15-day DL
# 3        placed on 15-day DL with sprained left foot
# 4        placed on 15-day DL with strained abdominal

# %%
no_dots_df_copy = no_dots_df.copy()

# %%
no_dots_df_copy.head()
# Out:
#    Unnamed: 0       Date        Team Acquired     Relinquished  \
# 0           0 2000-03-23     Rockies      NaN     John Thomson
# 1           1 2000-04-01  Devil Rays      NaN   Wilson Alvarez
# 2           2 2000-04-01     Dodgers      NaN    Antonio Osuna
# 3           3 2000-04-08        Mets      NaN  Darryl Hamilton
# 4           4 2000-04-08     Orioles      NaN      Mike Timlin
#
#                                                Notes
# 0  placed on 60-day DL recovering from surgery on...
# 1                                       placed on DL
# 2                                placed on 15-day DL
# 3        placed on 15-day DL with sprained left foot
# 4        placed on 15-day DL with strained abdominal

# %%
# you need to drop columns with NaN in acquired

# %%
import numpy as np
abcd =  no_dots_df_copy.replace(np.nan, '', regex=True)
no_dots_df_copy['person'] = abcd['Acquired']+abcd['Relinquished']

# %%
no_dots_df_copy.head()
# Out:
#    Unnamed: 0       Date        Team Acquired     Relinquished  \
# 0           0 2000-03-23     Rockies      NaN     John Thomson
# 1           1 2000-04-01  Devil Rays      NaN   Wilson Alvarez
# 2           2 2000-04-01     Dodgers      NaN    Antonio Osuna
# 3           3 2000-04-08        Mets      NaN  Darryl Hamilton
# 4           4 2000-04-08     Orioles      NaN      Mike Timlin
#
#                                                Notes           person
# 0  placed on 60-day DL recovering from surgery on...     John Thomson
# 1                                       placed on DL   Wilson Alvarez
# 2                                placed on 15-day DL    Antonio Osuna
# 3        placed on 15-day DL with sprained left foot  Darryl Hamilton
# 4        placed on 15-day DL with strained abdominal      Mike Timlin

# %%
test = no_dots_df_copy.sort_values(['person','Date'])
test.head(10)
# Out:
#        Unnamed: 0       Date      Team                     Acquired  \
# 3537         3537 2005-05-10    Astros                          NaN
# 5583         5583 2007-07-04      Mets                          NaN
# 5978         5978 2007-09-21    Royals                          NaN
# 15776       15776 2016-06-30  Mariners                          NaN
# 17216       17216 2017-06-23    Padres                          NaN
# 17144       17144 2017-06-15   Red Sox                          NaN
# 17335       17335 2017-07-06   Red Sox  (Christopher) Brian Johnson
# 18974       18974 2018-07-08   Red Sox                          NaN
# 19047       19047 2018-07-15   Red Sox  (Christopher) Brian Johnson
# 19892       19892 2019-04-06   Red Sox                          NaN
#
#                       Relinquished  \
# 3537                           NaN
# 5583                           NaN
# 5978                           NaN
# 15776                          NaN
# 17216                          NaN
# 17144  (Christopher) Brian Johnson
# 17335                          NaN
# 18974  (Christopher) Brian Johnson
# 19047                          NaN
# 19892  (Christopher) Brian Johnson
#
#                                                    Notes  \
# 3537      placed on 15-day DL with right shoulder injury
# 5583   transferred to 60-day DL with fractured right ...
# 5978                            transferred to 60-day DL
# 15776      placed on 15-day DL with fractured right hand
# 17216                           activated from 10-day DL
# 17144  placed on 10-day DL with left shoulder impinge...
# 17335                           activated from 10-day DL
# 18974     placed on 10-day DL with left hip inflammation
# 19047                           activated from 10-day DL
# 19892   placed on 10-day IL with left elbow inflammation
#
#                             person
# 3537
# 5583
# 5978
# 15776
# 17216
# 17144  (Christopher) Brian Johnson
# 17335  (Christopher) Brian Johnson
# 18974  (Christopher) Brian Johnson
# 19047  (Christopher) Brian Johnson
# 19892  (Christopher) Brian Johnson

# %%
# test['Notes'].unique()

# %%
is_prev_relinquished = test['Relinquished'].shift(1)==test['Acquired']
test['previous_is_relinquished'] = is_prev_relinquished

# %%
def get_day_num(x):
    return x.days
test['known_injury_duration'] = test['Date'].diff().fillna(0).apply(get_day_num)*test['previous_is_relinquished']

# %%
def date_negator(x):
    if x == 0:
        return np.nan
    return x
test['known_injury_duration'] = test['known_injury_duration'].apply(date_negator)
test.head()
# Out:
#        Unnamed: 0       Date      Team Acquired Relinquished  \
# 3537         3537 2005-05-10    Astros      NaN          NaN
# 5583         5583 2007-07-04      Mets      NaN          NaN
# 5978         5978 2007-09-21    Royals      NaN          NaN
# 15776       15776 2016-06-30  Mariners      NaN          NaN
# 17216       17216 2017-06-23    Padres      NaN          NaN
#
#                                                    Notes person  \
# 3537      placed on 15-day DL with right shoulder injury
# 5583   transferred to 60-day DL with fractured right ...
# 5978                            transferred to 60-day DL
# 15776      placed on 15-day DL with fractured right hand
# 17216                           activated from 10-day DL
#
#        previous_is_relinquished  known_injury_duration
# 3537                      False                    NaN
# 5583                      False                    NaN
# 5978                      False                    NaN
# 15776                     False                    NaN
# 17216                     False                    NaN

# %%
test['Date'].max()
# Out:
# Timestamp('2019-11-04 00:00:00')

# %%
def contains_scott(x):
    if 'giambi' in x.lower():
        return True
    return False

# %%
test[test['person'].apply(contains_scott)]
# Out:
#        Unnamed: 0       Date       Team       Acquired   Relinquished  \
# 2681         2681 2004-05-22    Yankees            NaN   Jason Giambi
# 2755         2755 2004-06-06    Yankees   Jason Giambi            NaN
# 3026         3026 2004-07-30    Yankees            NaN   Jason Giambi
# 3237         3237 2004-09-14    Yankees   Jason Giambi            NaN
# 5402         5402 2007-06-01    Yankees            NaN   Jason Giambi
# 5749         5749 2007-08-07    Yankees   Jason Giambi            NaN
# 7840         7840 2009-07-20  Athletics            NaN   Jason Giambi
# 7933         7933 2009-08-07  Athletics   Jason Giambi            NaN
# 10023       10023 2011-07-26    Rockies            NaN   Jason Giambi
# 10120       10120 2011-08-12    Rockies   Jason Giambi            NaN
# 11173       11173 2012-07-24    Rockies            NaN   Jason Giambi
# 11404       11404 2012-09-01    Rockies   Jason Giambi            NaN
# 11653       11653 2013-03-25    Indians            NaN   Jason Giambi
# 11766       11766 2013-04-12    Indians   Jason Giambi            NaN
# 12932       12932 2014-03-30    Indians            NaN   Jason Giambi
# 13057       13057 2014-04-21    Indians   Jason Giambi            NaN
# 13127       13127 2014-05-05    Indians            NaN   Jason Giambi
# 13208       13208 2014-05-20    Indians   Jason Giambi            NaN
# 13332       13332 2014-06-12    Indians            NaN   Jason Giambi
# 13520       13520 2014-07-12    Indians            NaN   Jason Giambi
# 13787       13787 2014-09-01    Indians   Jason Giambi            NaN
# 24             24 2000-08-23  Athletics            NaN  Jeremy Giambi
# 360           360 2001-06-10  Athletics  Jeremy Giambi            NaN
# 2036         2036 2003-06-28    Red Sox            NaN  Jeremy Giambi
# 2112         2112 2003-07-17    Red Sox  Jeremy Giambi            NaN
# 2189         2189 2003-08-05    Red Sox            NaN  Jeremy Giambi
#
#                                                    Notes         person  \
# 2681       placed on 15-day DL with sprained right ankle   Jason Giambi
# 2755                            activated from 15-day DL   Jason Giambi
# 3026   placed on 15-day DL with unspecified benign tumor   Jason Giambi
# 3237                            activated from 15-day DL   Jason Giambi
# 5402   placed on 15-day DL with foot injury (plantar ...   Jason Giambi
# 5749                            activated from 15-day DL   Jason Giambi
# 7840   placed on 15-day DL with strained right quadricep   Jason Giambi
# 7933                            activated from 15-day DL   Jason Giambi
# 10023  placed on 15-day DL with strained left quadriceps   Jason Giambi
# 10120                           activated from 15-day DL   Jason Giambi
# 11173           placed on 15-day DL with viral infection   Jason Giambi
# 11404                           activated from 15-day DL   Jason Giambi
# 11653       placed on 15-day DL with strained lower back   Jason Giambi
# 11766                           activated from 15-day DL   Jason Giambi
# 12932             placed on 15-day DL with fractured rib   Jason Giambi
# 13057                           activated from 15-day DL   Jason Giambi
# 13127       placed on 15-day DL with strained right calf   Jason Giambi
# 13208                           activated from 15-day DL   Jason Giambi
# 13332    placed on 15-day DL with left knee inflammation   Jason Giambi
# 13520  transferred to 60-day DL with left knee inflam...   Jason Giambi
# 13787                           activated from 60-day DL   Jason Giambi
# 24                                   placed on 15-day DL  Jeremy Giambi
# 360                             activated from 15-day DL  Jeremy Giambi
# 2036   placed on 15-day DL with bursitis in left shou...  Jeremy Giambi
# 2112                            activated from 15-day DL  Jeremy Giambi
# 2189   placed on 15-day DL with left shoulder tendinitis  Jeremy Giambi
#
#        previous_is_relinquished  known_injury_duration
# 2681                      False                    NaN
# 2755                       True                   15.0
# 3026                      False                    NaN
# 3237                       True                   46.0
# 5402                      False                    NaN
# 5749                       True                   67.0
# 7840                      False                    NaN
# 7933                       True                   18.0
# 10023                     False                    NaN
# 10120                      True                   17.0
# 11173                     False                    NaN
# 11404                      True                   39.0
# 11653                     False                    NaN
# 11766                      True                   18.0
# 12932                     False                    NaN
# 13057                      True                   22.0
# 13127                     False                    NaN
# 13208                      True                   15.0
# 13332                     False                    NaN
# 13520                     False                    NaN
# 13787                      True                   51.0
# 24                        False                    NaN
# 360                        True                  291.0
# 2036                      False                    NaN
# 2112                       True                   19.0
# 2189                      False                    NaN

# %%
test.head(10)
# Out:
#        Unnamed: 0       Date      Team                     Acquired  \
# 3537         3537 2005-05-10    Astros                          NaN
# 5583         5583 2007-07-04      Mets                          NaN
# 5978         5978 2007-09-21    Royals                          NaN
# 15776       15776 2016-06-30  Mariners                          NaN
# 17216       17216 2017-06-23    Padres                          NaN
# 17144       17144 2017-06-15   Red Sox                          NaN
# 17335       17335 2017-07-06   Red Sox  (Christopher) Brian Johnson
# 18974       18974 2018-07-08   Red Sox                          NaN
# 19047       19047 2018-07-15   Red Sox  (Christopher) Brian Johnson
# 19892       19892 2019-04-06   Red Sox                          NaN
#
#                       Relinquished  \
# 3537                           NaN
# 5583                           NaN
# 5978                           NaN
# 15776                          NaN
# 17216                          NaN
# 17144  (Christopher) Brian Johnson
# 17335                          NaN
# 18974  (Christopher) Brian Johnson
# 19047                          NaN
# 19892  (Christopher) Brian Johnson
#
#                                                    Notes  \
# 3537      placed on 15-day DL with right shoulder injury
# 5583   transferred to 60-day DL with fractured right ...
# 5978                            transferred to 60-day DL
# 15776      placed on 15-day DL with fractured right hand
# 17216                           activated from 10-day DL
# 17144  placed on 10-day DL with left shoulder impinge...
# 17335                           activated from 10-day DL
# 18974     placed on 10-day DL with left hip inflammation
# 19047                           activated from 10-day DL
# 19892   placed on 10-day IL with left elbow inflammation
#
#                             person  previous_is_relinquished  \
# 3537                                                   False
# 5583                                                   False
# 5978                                                   False
# 15776                                                  False
# 17216                                                  False
# 17144  (Christopher) Brian Johnson                     False
# 17335  (Christopher) Brian Johnson                      True
# 18974  (Christopher) Brian Johnson                     False
# 19047  (Christopher) Brian Johnson                      True
# 19892  (Christopher) Brian Johnson                     False
#
#        known_injury_duration
# 3537                     NaN
# 5583                     NaN
# 5978                     NaN
# 15776                    NaN
# 17216                    NaN
# 17144                    NaN
# 17335                   21.0
# 18974                    NaN
# 19047                    7.0
# 19892                    NaN

# %%
tbm = pd.read_csv('baseball_datasets/Player DataFrame')

# %%
test['known_injury_duration']
# Out:
# 3537       NaN
# 5583       NaN
# 5978       NaN
# 15776      NaN
# 17216      NaN
# 17144      NaN
# 17335     21.0
# 18974      NaN
# 19047      7.0
# 19892      NaN
# 20405     69.0
# 20526      NaN
# 20799     35.0
# 13361      NaN
# 13456     15.0
# 14489      NaN
# 14677      NaN
# 14940      NaN
# 15152     63.0
# 14767      NaN
# 14979     33.0
# 17153      NaN
# 17435     36.0
# 18883      NaN
# 19045     15.0
# 19804      NaN
# 19960     21.0
# 20197      NaN
# 20384      NaN
# 21045     80.0
#          ...
# 15414      NaN
# 16421    191.0
# 17190      NaN
# 17292     10.0
# 17445      NaN
# 17919      NaN
# 18016     41.0
# 20623      NaN
# 20721     11.0
# 12320      NaN
# 12646     51.0
# 17217      NaN
# 17178      NaN
# 19442      NaN
# 18879      NaN
# 21006      NaN
# 21092      NaN
# 21055      NaN
# 21189      NaN
# 21212      NaN
# 21056      NaN
# 21093      NaN
# 21067      NaN
# 21099      NaN
# 21068      NaN
# 4147       NaN
# 21050      NaN
# 16909      NaN
# 16906      NaN
# 21070      NaN
# Name: known_injury_duration, Length: 21367, dtype: float64

# %%
pd.merge(test,tbm,how='inner',left_on='person',right_on='nameGiven')
# Out:
#     Unnamed: 0_x       Date        Team         Acquired     Relinquished  \
# 0          16854 2017-05-09      Royals              NaN  Scott Alexander
# 1          16854 2017-05-09      Royals              NaN  Scott Alexander
# 2          16854 2017-05-09      Royals              NaN  Scott Alexander
# 3          16854 2017-05-09      Royals              NaN  Scott Alexander
# 4          17086 2017-06-07      Royals  Scott Alexander              NaN
# 5          17086 2017-06-07      Royals  Scott Alexander              NaN
# 6          17086 2017-06-07      Royals  Scott Alexander              NaN
# 7          17086 2017-06-07      Royals  Scott Alexander              NaN
# 8          20375 2019-06-11     Dodgers              NaN  Scott Alexander
# 9          20375 2019-06-11     Dodgers              NaN  Scott Alexander
# 10         20375 2019-06-11     Dodgers              NaN  Scott Alexander
# 11         20375 2019-06-11     Dodgers              NaN  Scott Alexander
# 12         20782 2019-08-02     Dodgers              NaN  Scott Alexander
# 13         20782 2019-08-02     Dodgers              NaN  Scott Alexander
# 14         20782 2019-08-02     Dodgers              NaN  Scott Alexander
# 15         20782 2019-08-02     Dodgers              NaN  Scott Alexander
# 16         21306 2019-11-04     Dodgers  Scott Alexander              NaN
# 17         21306 2019-11-04     Dodgers  Scott Alexander              NaN
# 18         21306 2019-11-04     Dodgers  Scott Alexander              NaN
# 19         21306 2019-11-04     Dodgers  Scott Alexander              NaN
# 20          1714 2003-04-19  Devil Rays              NaN       Travis Lee
# 21          1714 2003-04-19  Devil Rays              NaN       Travis Lee
# 22          1714 2003-04-19  Devil Rays              NaN       Travis Lee
# 23          1714 2003-04-19  Devil Rays              NaN       Travis Lee
# 24          1714 2003-04-19  Devil Rays              NaN       Travis Lee
# 25          1714 2003-04-19  Devil Rays              NaN       Travis Lee
# 26          1714 2003-04-19  Devil Rays              NaN       Travis Lee
# 27          1714 2003-04-19  Devil Rays              NaN       Travis Lee
# 28          1714 2003-04-19  Devil Rays              NaN       Travis Lee
# 29          1750 2003-04-29  Devil Rays       Travis Lee              NaN
# ..           ...        ...         ...              ...              ...
# 62          2586 2004-05-01     Yankees              NaN       Travis Lee
# 63          2586 2004-05-01     Yankees              NaN       Travis Lee
# 64          2586 2004-05-01     Yankees              NaN       Travis Lee
# 65          2637 2004-05-13     Yankees              NaN       Travis Lee
# 66          2637 2004-05-13     Yankees              NaN       Travis Lee
# 67          2637 2004-05-13     Yankees              NaN       Travis Lee
# 68          2637 2004-05-13     Yankees              NaN       Travis Lee
# 69          2637 2004-05-13     Yankees              NaN       Travis Lee
# 70          2637 2004-05-13     Yankees              NaN       Travis Lee
# 71          2637 2004-05-13     Yankees              NaN       Travis Lee
# 72          2637 2004-05-13     Yankees              NaN       Travis Lee
# 73          2637 2004-05-13     Yankees              NaN       Travis Lee
# 74          3501 2005-05-02  Devil Rays              NaN       Travis Lee
# 75          3501 2005-05-02  Devil Rays              NaN       Travis Lee
# 76          3501 2005-05-02  Devil Rays              NaN       Travis Lee
# 77          3501 2005-05-02  Devil Rays              NaN       Travis Lee
# 78          3501 2005-05-02  Devil Rays              NaN       Travis Lee
# 79          3501 2005-05-02  Devil Rays              NaN       Travis Lee
# 80          3501 2005-05-02  Devil Rays              NaN       Travis Lee
# 81          3501 2005-05-02  Devil Rays              NaN       Travis Lee
# 82          3501 2005-05-02  Devil Rays              NaN       Travis Lee
# 83          3584 2005-05-20  Devil Rays       Travis Lee              NaN
# 84          3584 2005-05-20  Devil Rays       Travis Lee              NaN
# 85          3584 2005-05-20  Devil Rays       Travis Lee              NaN
# 86          3584 2005-05-20  Devil Rays       Travis Lee              NaN
# 87          3584 2005-05-20  Devil Rays       Travis Lee              NaN
# 88          3584 2005-05-20  Devil Rays       Travis Lee              NaN
# 89          3584 2005-05-20  Devil Rays       Travis Lee              NaN
# 90          3584 2005-05-20  Devil Rays       Travis Lee              NaN
# 91          3584 2005-05-20  Devil Rays       Travis Lee              NaN
#
#                                                 Notes           person  \
# 0   placed on 10-day DL with strained right hamstring  Scott Alexander
# 1   placed on 10-day DL with strained right hamstring  Scott Alexander
# 2   placed on 10-day DL with strained right hamstring  Scott Alexander
# 3   placed on 10-day DL with strained right hamstring  Scott Alexander
# 4                            activated from 10-day DL  Scott Alexander
# 5                            activated from 10-day DL  Scott Alexander
# 6                            activated from 10-day DL  Scott Alexander
# 7                            activated from 10-day DL  Scott Alexander
# 8   placed on 10-day IL with left forearm inflamma...  Scott Alexander
# 9   placed on 10-day IL with left forearm inflamma...  Scott Alexander
# 10  placed on 10-day IL with left forearm inflamma...  Scott Alexander
# 11  placed on 10-day IL with left forearm inflamma...  Scott Alexander
# 12  transferred to 60-day IL with left forearm inf...  Scott Alexander
# 13  transferred to 60-day IL with left forearm inf...  Scott Alexander
# 14  transferred to 60-day IL with left forearm inf...  Scott Alexander
# 15  transferred to 60-day IL with left forearm inf...  Scott Alexander
# 16                           activated from 60-day IL  Scott Alexander
# 17                           activated from 60-day IL  Scott Alexander
# 18                           activated from 60-day IL  Scott Alexander
# 19                           activated from 60-day IL  Scott Alexander
# 20                                placed on 15-day DL       Travis Lee
# 21                                placed on 15-day DL       Travis Lee
# 22                                placed on 15-day DL       Travis Lee
# 23                                placed on 15-day DL       Travis Lee
# 24                                placed on 15-day DL       Travis Lee
# 25                                placed on 15-day DL       Travis Lee
# 26                                placed on 15-day DL       Travis Lee
# 27                                placed on 15-day DL       Travis Lee
# 28                                placed on 15-day DL       Travis Lee
# 29                           activated from 15-day DL       Travis Lee
# ..                                                ...              ...
# 62                                placed on 15-day DL       Travis Lee
# 63                                placed on 15-day DL       Travis Lee
# 64                                placed on 15-day DL       Travis Lee
# 65                           transferred to 60-day DL       Travis Lee
# 66                           transferred to 60-day DL       Travis Lee
# 67                           transferred to 60-day DL       Travis Lee
# 68                           transferred to 60-day DL       Travis Lee
# 69                           transferred to 60-day DL       Travis Lee
# 70                           transferred to 60-day DL       Travis Lee
# 71                           transferred to 60-day DL       Travis Lee
# 72                           transferred to 60-day DL       Travis Lee
# 73                           transferred to 60-day DL       Travis Lee
# 74              placed on 15-day DL with groin injury       Travis Lee
# 75              placed on 15-day DL with groin injury       Travis Lee
# 76              placed on 15-day DL with groin injury       Travis Lee
# 77              placed on 15-day DL with groin injury       Travis Lee
# 78              placed on 15-day DL with groin injury       Travis Lee
# 79              placed on 15-day DL with groin injury       Travis Lee
# 80              placed on 15-day DL with groin injury       Travis Lee
# 81              placed on 15-day DL with groin injury       Travis Lee
# 82              placed on 15-day DL with groin injury       Travis Lee
# 83                           activated from 15-day DL       Travis Lee
# 84                           activated from 15-day DL       Travis Lee
# 85                           activated from 15-day DL       Travis Lee
# 86                           activated from 15-day DL       Travis Lee
# 87                           activated from 15-day DL       Travis Lee
# 88                           activated from 15-day DL       Travis Lee
# 89                           activated from 15-day DL       Travis Lee
# 90                           activated from 15-day DL       Travis Lee
# 91                           activated from 15-day DL       Travis Lee
#
#     previous_is_relinquished  known_injury_duration  Unnamed: 0_y  ...    R  \
# 0                      False                    NaN          2655  ...   39
# 1                      False                    NaN          2656  ...   42
# 2                      False                    NaN          2657  ...   34
# 3                      False                    NaN          2658  ...   52
# 4                       True                   29.0          2655  ...   39
# 5                       True                   29.0          2656  ...   42
# 6                       True                   29.0          2657  ...   34
# 7                       True                   29.0          2658  ...   52
# 8                      False                    NaN          2655  ...   39
# 9                      False                    NaN          2656  ...   42
# 10                     False                    NaN          2657  ...   34
# 11                     False                    NaN          2658  ...   52
# 12                     False                    NaN          2655  ...   39
# 13                     False                    NaN          2656  ...   42
# 14                     False                    NaN          2657  ...   34
# 15                     False                    NaN          2658  ...   52
# 16                      True                   94.0          2655  ...   39
# 17                      True                   94.0          2656  ...   42
# 18                      True                   94.0          2657  ...   34
# 19                      True                   94.0          2658  ...   52
# 20                     False                    NaN          2412  ...   35
# 21                     False                    NaN          2413  ...   96
# 22                     False                    NaN          2414  ...   94
# 23                     False                    NaN          2415  ...  100
# 24                     False                    NaN          2416  ...   80
# 25                     False                    NaN          2417  ...   46
# 26                     False                    NaN          2418  ...   46
# 27                     False                    NaN          2419  ...   41
# 28                     False                    NaN          2420  ...   31
# 29                      True                   10.0          2412  ...   35
# ..                       ...                    ...           ...  ...  ...
# 62                     False                    NaN          2418  ...   46
# 63                     False                    NaN          2419  ...   41
# 64                     False                    NaN          2420  ...   31
# 65                     False                    NaN          2412  ...   35
# 66                     False                    NaN          2413  ...   96
# 67                     False                    NaN          2414  ...   94
# 68                     False                    NaN          2415  ...  100
# 69                     False                    NaN          2416  ...   80
# 70                     False                    NaN          2417  ...   46
# 71                     False                    NaN          2418  ...   46
# 72                     False                    NaN          2419  ...   41
# 73                     False                    NaN          2420  ...   31
# 74                     False                    NaN          2412  ...   35
# 75                     False                    NaN          2413  ...   96
# 76                     False                    NaN          2414  ...   94
# 77                     False                    NaN          2415  ...  100
# 78                     False                    NaN          2416  ...   80
# 79                     False                    NaN          2417  ...   46
# 80                     False                    NaN          2418  ...   46
# 81                     False                    NaN          2419  ...   41
# 82                     False                    NaN          2420  ...   31
# 83                      True                   18.0          2412  ...   35
# 84                      True                   18.0          2413  ...   96
# 85                      True                   18.0          2414  ...   94
# 86                      True                   18.0          2415  ...  100
# 87                      True                   18.0          2416  ...   80
# 88                      True                   18.0          2417  ...   46
# 89                      True                   18.0          2418  ...   46
# 90                      True                   18.0          2419  ...   41
# 91                      True                   18.0          2420  ...   31
#
#       H  2B 3B  HR    RBI   BB     SO        BA        nameGiven
# 0    84  15  6  13   29.0   21   88.0  0.247788  Scott Alexander
# 1    81  18  3  17   31.0   28   84.0  0.248466  Scott Alexander
# 2    62  10  0  10   36.0   31   69.0  0.210169  Scott Alexander
# 3    99  25  3  20   57.0   19   83.0  0.262599  Scott Alexander
# 4    84  15  6  13   29.0   21   88.0  0.247788  Scott Alexander
# 5    81  18  3  17   31.0   28   84.0  0.248466  Scott Alexander
# 6    62  10  0  10   36.0   31   69.0  0.210169  Scott Alexander
# 7    99  25  3  20   57.0   19   83.0  0.262599  Scott Alexander
# 8    84  15  6  13   29.0   21   88.0  0.247788  Scott Alexander
# 9    81  18  3  17   31.0   28   84.0  0.248466  Scott Alexander
# 10   62  10  0  10   36.0   31   69.0  0.210169  Scott Alexander
# 11   99  25  3  20   57.0   19   83.0  0.262599  Scott Alexander
# 12   84  15  6  13   29.0   21   88.0  0.247788  Scott Alexander
# 13   81  18  3  17   31.0   28   84.0  0.248466  Scott Alexander
# 14   62  10  0  10   36.0   31   69.0  0.210169  Scott Alexander
# 15   99  25  3  20   57.0   19   83.0  0.262599  Scott Alexander
# 16   84  15  6  13   29.0   21   88.0  0.247788  Scott Alexander
# 17   81  18  3  17   31.0   28   84.0  0.248466  Scott Alexander
# 18   62  10  0  10   36.0   31   69.0  0.210169  Scott Alexander
# 19   99  25  3  20   57.0   19   83.0  0.262599  Scott Alexander
# 20   74  19  3  14   40.0   22   81.0  0.254296       Travis Lee
# 21  150  41  3  28  109.0   68  111.0  0.311203       Travis Lee
# 22  148  42  0  33  108.0   79  123.0  0.304527       Travis Lee
# 23  140  31  1  42  117.0  100  111.0  0.308370       Travis Lee
# 24  145  25  2  24  100.0  102  115.0  0.266055       Travis Lee
# 25   92  19  0  16   49.0   41   67.0  0.272189       Travis Lee
# 26  110  29  0  13   50.0   51   94.0  0.277778       Travis Lee
# 27   91  16  0  13   57.0   36   78.0  0.280000       Travis Lee
# 28   53   8  1  12   37.0   32   79.0  0.202290       Travis Lee
# 29   74  19  3  14   40.0   22   81.0  0.254296       Travis Lee
# ..  ...  .. ..  ..    ...  ...    ...       ...              ...
# 62  110  29  0  13   50.0   51   94.0  0.277778       Travis Lee
# 63   91  16  0  13   57.0   36   78.0  0.280000       Travis Lee
# 64   53   8  1  12   37.0   32   79.0  0.202290       Travis Lee
# 65   74  19  3  14   40.0   22   81.0  0.254296       Travis Lee
# 66  150  41  3  28  109.0   68  111.0  0.311203       Travis Lee
# 67  148  42  0  33  108.0   79  123.0  0.304527       Travis Lee
# 68  140  31  1  42  117.0  100  111.0  0.308370       Travis Lee
# 69  145  25  2  24  100.0  102  115.0  0.266055       Travis Lee
# 70   92  19  0  16   49.0   41   67.0  0.272189       Travis Lee
# 71  110  29  0  13   50.0   51   94.0  0.277778       Travis Lee
# 72   91  16  0  13   57.0   36   78.0  0.280000       Travis Lee
# 73   53   8  1  12   37.0   32   79.0  0.202290       Travis Lee
# 74   74  19  3  14   40.0   22   81.0  0.254296       Travis Lee
# 75  150  41  3  28  109.0   68  111.0  0.311203       Travis Lee
# 76  148  42  0  33  108.0   79  123.0  0.304527       Travis Lee
# 77  140  31  1  42  117.0  100  111.0  0.308370       Travis Lee
# 78  145  25  2  24  100.0  102  115.0  0.266055       Travis Lee
# 79   92  19  0  16   49.0   41   67.0  0.272189       Travis Lee
# 80  110  29  0  13   50.0   51   94.0  0.277778       Travis Lee
# 81   91  16  0  13   57.0   36   78.0  0.280000       Travis Lee
# 82   53   8  1  12   37.0   32   79.0  0.202290       Travis Lee
# 83   74  19  3  14   40.0   22   81.0  0.254296       Travis Lee
# 84  150  41  3  28  109.0   68  111.0  0.311203       Travis Lee
# 85  148  42  0  33  108.0   79  123.0  0.304527       Travis Lee
# 86  140  31  1  42  117.0  100  111.0  0.308370       Travis Lee
# 87  145  25  2  24  100.0  102  115.0  0.266055       Travis Lee
# 88   92  19  0  16   49.0   41   67.0  0.272189       Travis Lee
# 89  110  29  0  13   50.0   51   94.0  0.277778       Travis Lee
# 90   91  16  0  13   57.0   36   78.0  0.280000       Travis Lee
# 91   53   8  1  12   37.0   32   79.0  0.202290       Travis Lee
#
# [92 rows x 27 columns]
