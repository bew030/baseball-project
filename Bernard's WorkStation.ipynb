# %%
# imports

import json
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
import warnings
pd.options.mode.chained_assignment = None
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Reading in the Data

# %% [markdown]
# Before we can do any data analysis, we need to be able to actually find and read in data. After doing some research, we found a website that basically had an archive for data for multiple sports (including baseball). Because we couldn't just download the datasets and because we didn't want to manually type out the datapoints, we decided to utilize web scraping to read in the data for us.
#
# The first step was to come up with all the links that we were planning to scrape. Because the first page of the search result contained hyperlinks to all the other pages of the search result, we scraped the first page for all the HTMLs and then created a list of URLs to scrape.

# %%
# base link used for each page 
base_link = 'https://www.prosportstransactions.com/baseball/Search/' 
# link to the first page of the search result 
link = 'https://www.prosportstransactions.com/baseball/Search/SearchResults.php?Player=&Team=&BeginDate=2000-01-01&EndDate=2019-11-19&DLChkBx=yes&submit=Search'

# %%
r = requests.get(link)
urlText = r.text

# %%
soup = BeautifulSoup(urlText, 'html.parser') # reads everything into something more readable than HTML

# %%
all_links  = soup.find_all('a') # finds all links within the page

# %%
# removes first and last 4 links, which are extraneous links
important_links = [x.get('href') for x in all_links[4:-4]] 

# adds base URL to each link to make each link a proper URL link for each page 
final_links = [link]
final_links = final_links+[base_link+x for x in important_links]

# %% [markdown]
# final_links contains the final list of all the URLs we're planning to scrape. We can then create a method that will loop through the links and properly scrape the data and concatenate it onto a dataframe. This method is timed and only used once: delays are set so that the website isn’t overloaded with traffic, and once the method runs through once the dataset gets saved as a csv to ensure that the website isn’t abused.

# %%
def number_cycles(links, n=3,sleep_time=2):
    '''
    This method takes in a list of links and scrapes the data, neatly organizing it into a dataframe. 
    Parameters: 
        Links: the list of URL links that you want to scrape 
        n: the number of links you want to read in from the list, default 3 
        sleep_time: the time the loop waits before reading in the website, default 2 seconds, TIME SHOULD BE INCREASED
            IF LENGTH OF LIST OF URLS IS LARGE
    Returns: 
        returns the dataframe containing the data scraped from all the links from the inputted list 
    '''
    final_df = pd.DataFrame()
    for i in range(n):
        print('working on page '+str(i))
        sleep(sleep_time)
        test = pd.read_html(links[i],header = 0)[0]
        final_df = pd.concat([final_df, test],ignore_index = True)
    return final_df

# %%
df = number_cycles(final_links,20,sleep_time=0)
# Out:
# working on page 0
# working on page 1
# working on page 2
# working on page 3
# working on page 4
# working on page 5
# working on page 6
# working on page 7
# working on page 8
# working on page 9
# working on page 10
# working on page 11
# working on page 12
# working on page 13
# working on page 14
# working on page 15
# working on page 16
# working on page 17
# working on page 18
# working on page 19

# %%
df.to_csv('baseball_datasets/webscraped_dataset.csv')

# %%
df.head()
# Out:
#          Date        Team Acquired       Relinquished  \
# 0  2000-03-23     Rockies      NaN     • John Thomson
# 1  2000-04-01  Devil Rays      NaN   • Wilson Alvarez
# 2  2000-04-01     Dodgers      NaN    • Antonio Osuna
# 3  2000-04-08        Mets      NaN  • Darryl Hamilton
# 4  2000-04-08     Orioles      NaN      • Mike Timlin
#
#                                                Notes
# 0  placed on 60-day DL recovering from surgery on...
# 1                                       placed on DL
# 2                                placed on 15-day DL
# 3        placed on 15-day DL with sprained left foot
# 4        placed on 15-day DL with strained abdominal

# %% [markdown]
# Now we have a dataset that we can use! We can begin to analyze and clean it.

# %% [markdown]
# # Understanding and Cleaning the Dataset

# %%
# reading in CSV 
df = pd.read_csv('baseball_datasets/webscraped_dataset.csv')

# %%
def dot_remover(x):
    '''
    '''
    if not (x == x):
        return x 
    else: 
        return x[2:]
    
def dot_cleaner(df):
    df['Acquired'] = df['Acquired'].apply(dot_remover)
    df['Relinquished'] = df['Relinquished'].apply(dot_remover)
    return df

# %%
no_dots_df = dot_cleaner(df)

# %%
no_dots_df['Date'] = pd.to_datetime(no_dots_df['Date'])

# %%
no_dots_df.head()
# Out:
#    Unnamed: 0       Date        Team Acquired     Relinquished  \
# 0           0 2000-03-23     Rockies      NaN     John Thomson
# 1           1 2000-04-01  Devil Rays      NaN   Wilson Alvarez
# 2           2 2000-04-01     Dodgers      NaN    Antonio Osuna
# 3           3 2000-04-08        Mets      NaN  Darryl Hamilton
# 4           4 2000-04-08     Orioles      NaN      Mike Timlin
#
#                                                Notes
# 0  placed on 60-day DL recovering from surgery on...
# 1                                       placed on DL
# 2                                placed on 15-day DL
# 3        placed on 15-day DL with sprained left foot
# 4        placed on 15-day DL with strained abdominal

# %%
no_dots_df
# Out:
#      Unnamed: 0       Date          Team                   Acquired  \
# 0             0 2000-03-23       Rockies                        NaN
# 1             1 2000-04-01    Devil Rays                        NaN
# 2             2 2000-04-01       Dodgers                        NaN
# 3             3 2000-04-08          Mets                        NaN
# 4             4 2000-04-08       Orioles                        NaN
# 5             5 2000-04-08        Padres                        NaN
# 6             6 2000-04-08          Cubs         Glenallen Hill Sr.
# 7             7 2000-05-24        Braves                        NaN
# 8             8 2000-05-24       Indians                        NaN
# 9             9 2000-05-24        Giants                Ellis Burks
# 10           10 2000-06-21        Astros                        NaN
# 11           11 2000-06-21       Rangers                        NaN
# 12           12 2000-07-03    Devil Rays             Vinny Castilla
# 13           13 2000-07-03  Diamondbacks                        NaN
# 14           14 2000-07-03       Pirates            Scott Sauerbeck
# 15           15 2000-07-03     Blue Jays   Peter Munro / Pete Munro
# 16           16 2000-07-07      Mariners                        NaN
# 17           17 2000-07-07      Mariners              Freddy Garcia
# 18           18 2000-07-07          Reds                        NaN
# 19           19 2000-07-12      Phillies                        NaN
# 20           20 2000-07-12       Yankees                        NaN
# 21           21 2000-07-24      Mariners  Alex Rodriguez (Enmanuel)
# 22           22 2000-07-26        Angels          Scott Schoeneweis
# 23           23 2000-07-31        Astros                        NaN
# 24           24 2000-08-23     Athletics                        NaN
# 25           25 2000-08-23      Mariners                        NaN
# 26           26 2000-09-26       Indians                        NaN
# 27           27 2000-10-04        Angels              Jason Dickson
# 28           28 2000-10-04        Angels               Jeff DaVanon
# 29           29 2000-10-04        Angels             Mike Colangelo
# ..          ...        ...           ...                        ...
# 470         470 2001-07-02        Angels                        NaN
# 471         471 2001-07-02       Brewers                        NaN
# 472         472 2001-07-02       Rangers                        NaN
# 473         473 2001-07-02          Reds               Dennys Reyes
# 474         474 2001-07-02        Angels           Jose Molina (B.)
# 475         475 2001-07-03          Mets                        NaN
# 476         476 2001-07-03          Mets            Edgardo Alfonzo
# 477         477 2001-07-03        Padres             Tony Gwynn Sr.
# 478         478 2001-07-03        Padres              Wiki Gonzalez
# 479         479 2001-07-03       Pirates                John Wehner
# 480         480 2001-07-03     White Sox                        NaN
# 481         481 2001-07-04      Mariners                        NaN
# 482         482 2001-07-04          Mets                 Donne Wall
# 483         483 2001-07-04        Padres         Sterling Hitchcock
# 484         484 2001-07-05        Angels              Ismael Valdes
# 485         485 2001-07-05       Orioles              Chris Richard
# 486         486 2001-07-06        Braves                        NaN
# 487         487 2001-07-06       Brewers                        NaN
# 488         488 2001-07-06          Cubs                        NaN
# 489         489 2001-07-06      Phillies              Cliff Politte
# 490         490 2001-07-06        Royals                 Mark Quinn
# 491         491 2001-07-06      Phillies              Eddie Oropesa
# 492         492 2001-07-07     Cardinals                        NaN
# 493         493 2001-07-07       Red Sox                        NaN
# 494         494 2001-07-07         Twins              Jason Maxwell
# 495         495 2001-07-08       Rockies                        NaN
# 496         496 2001-07-08       Rockies                        NaN
# 497         497 2001-07-11       Rangers      Dan Kolb / Danny Kolb
# 498         498 2001-07-12        Braves                        NaN
# 499         499 2001-07-12  Diamondbacks    Matt Williams (Derrick)
#
#                             Relinquished  \
# 0                           John Thomson
# 1                         Wilson Alvarez
# 2                          Antonio Osuna
# 3                        Darryl Hamilton
# 4                            Mike Timlin
# 5                       Carlos Hernandez
# 6                                    NaN
# 7                        Kevin McGlinchy
# 8                             Paul Shuey
# 9                                    NaN
# 10                          Billy Wagner
# 11                         Darren Oliver
# 12                                   NaN
# 13                          Alex Cabrera
# 14                                   NaN
# 15                                   NaN
# 16   Frank Rodriguez / Frankie Rodriguez
# 17                                   NaN
# 18                     Osvaldo Fernandez
# 19                          Scott Aldred
# 20                         Shane Spencer
# 21                                   NaN
# 22                                   NaN
# 23                        Mitch Meluskey
# 24                         Jeremy Giambi
# 25                            Jay Buhner
# 26                          Charles Nagy
# 27                                   NaN
# 28                                   NaN
# 29                                   NaN
# ..                                   ...
# 470                           Tim Salmon
# 471                          Paul Rigdon
# 472                           J.D. Smart
# 473                                  NaN
# 474                                  NaN
# 475                       Jorge Velandia
# 476                                  NaN
# 477                                  NaN
# 478                                  NaN
# 479                                  NaN
# 480                          David Wells
# 481                          Stan Javier
# 482                                  NaN
# 483                                  NaN
# 484                                  NaN
# 485                                  NaN
# 486                       Bernard Gilkey
# 487                         James Mouton
# 488                        Rondell White
# 489                                  NaN
# 490                                  NaN
# 491                                  NaN
# 492                           Mike James
# 493                        Pete Schourek
# 494                                  NaN
# 495                Jose Jimenez (Antena)
# 496                           Kane Davis
# 497                                  NaN
# 498                        Rafael Furcal
# 499                                  NaN
#
#                                                  Notes
# 0    placed on 60-day DL recovering from surgery on...
# 1                                         placed on DL
# 2                                  placed on 15-day DL
# 3          placed on 15-day DL with sprained left foot
# 4          placed on 15-day DL with strained abdominal
# 5              placed on 15-day DL with strained groin
# 6                             activated from 15-day DL
# 7                                  placed on 15-day DL
# 8                                  placed on 15-day DL
# 9                             activated from 15-day DL
# 10                                 placed on 15-day DL
# 11                                 placed on 15-day DL
# 12                            activated from 15-day DL
# 13                                 placed on 15-day DL
# 14                            activated from 15-day DL
# 15                            activated from 15-day DL
# 16                                 placed on 15-day DL
# 17                            activated from 15-day DL
# 18                                 placed on 15-day DL
# 19                            transferred to 60-day DL
# 20                                 placed on 60-day DL
# 21                            activated from 15-day DL
# 22                            activated from 15-day DL
# 23                                 placed on 15-day DL
# 24                                 placed on 15-day DL
# 25                                 placed on 15-day DL
# 26   placed on 15-day DL with right elbow inflammation
# 27                            activated from 60-day DL
# 28                            activated from 60-day DL
# 29                            activated from 60-day DL
# ..                                                 ...
# 470  placed on 15-day DL with strained shoulder / u...
# 471  placed on 15-day DL with ulnar neuritis in rig...
# 472  placed on 15-day DL with right shoulder discom...
# 473                           activated from 15-day DL
# 474                           activated from 15-day DL
# 475     placed on 15-day DL with strained left oblique
# 476                           activated from 15-day DL
# 477                           activated from 15-day DL
# 478                           activated from 15-day DL
# 479                           activated from 15-day DL
# 480       placed on 15-day DL with strained lower back
# 481                                placed on 15-day DL
# 482                           activated from 15-day DL
# 483                           activated from 60-day DL
# 484                           activated from 15-day DL
# 485                           activated from 15-day DL
# 486                                       placed on DL
# 487   placed on 15-day DL with strained left hamstring
# 488  placed on 15-day DL with aggravated left groin...
# 489                           activated from 60-day DL
# 490                           activated from 15-day DL
# 491                           activated from 15-day DL
# 492  placed on 15-day DL with right shoulder inflam...
# 493   placed on 15-day DL with left elbow inflammation
# 494                           activated from 15-day DL
# 495  placed on 15-day DL with right shoulder inflam...
# 496  placed on 15-day DL with right elbow inflammation
# 497                           activated from 60-day DL
# 498                           transferred to 60-day DL
# 499                           activated from 15-day DL
#
# [500 rows x 6 columns]

# %%
# things to do: 
# save df as a external csv so that you don't have to constantly load it 
# rotate dataframe so that people injured and returned are all in one row

# %%
no_dots_df_copy = no_dots_df.copy()

# %%
no_dots_df_copy.head()
# Out:
#    Unnamed: 0       Date        Team Acquired     Relinquished  \
# 0           0 2000-03-23     Rockies      NaN     John Thomson
# 1           1 2000-04-01  Devil Rays      NaN   Wilson Alvarez
# 2           2 2000-04-01     Dodgers      NaN    Antonio Osuna
# 3           3 2000-04-08        Mets      NaN  Darryl Hamilton
# 4           4 2000-04-08     Orioles      NaN      Mike Timlin
#
#                                                Notes
# 0  placed on 60-day DL recovering from surgery on...
# 1                                       placed on DL
# 2                                placed on 15-day DL
# 3        placed on 15-day DL with sprained left foot
# 4        placed on 15-day DL with strained abdominal

# %%
# you need to drop columns with NaN in acquired

# %%
import numpy as np
abcd =  no_dots_df_copy.replace(np.nan, '', regex=True)
no_dots_df_copy['person'] = abcd['Acquired']+abcd['Relinquished']

# %%
len(no_dots_df_copy['person'].unique())
# Out:
# 300

# %%
final_df = pd.DataFrame()
names = no_dots_df_copy['person'].unique()
list_o_shit = []
for i in range(len(names)):
    name_df = no_dots_df_copy[((no_dots_df_copy['Acquired']==names[i]) | 
                            (no_dots_df_copy['Relinquished']==names[i]))]
    def is_relinquished(x):
        if x == x: 
            return 0 
        else: 
            return 1
    name_df['order stuff'] = name_df['Acquired'].apply(is_relinquished)
    index_stuff = list(name_df['order stuff'])
    list_fuckups = []
    for i in range(len(index_stuff)-1):
        if index_stuff[i] == index_stuff[i+1]:
            list_fuckups.append((i+(i+1))/2)
    for i in list_fuckups: 
        line = pd.DataFrame({"Date": np.nan, "Team": np.nan,'Acquired':np.nan, 'Relinquished':np.nan,
                        'Notes': np.nan, 'person':np.nan, 'number_rows': np.nan,'order stuff':(i-.5)//2}, index=[i])
        name_df = name_df.append(line, ignore_index=False)
        name_df = name_df.sort_index().reset_index(drop=True)
    if name_df.iloc[0]['Acquired'] == name_df.iloc[0]['Acquired']: # if acquired is first data point (no data on previous injury )
        name_df = name_df[1:]
    left = name_df[name_df['order stuff'] == 1.0].reset_index()
    right = name_df[name_df['order stuff'] == 0][['Date','Notes']].reset_index()
    new_df = pd.concat([left,right],axis = 1)
    list_o_shit.append(new_df)
    final_df = pd.concat([final_df,new_df])
final_df.columns = ['useless1','Date Relinquished','Team','useless2','Player','Injury','useless3',
                   'useless4','useless5','useless6','Date Returned','Notes about Return']
final_df = final_df[['Date Relinquished','Team','Player','Injury','Date Returned','Notes about Return']]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-52-5e6dd6588eee> in <module>
#      27     new_df = pd.concat([left,right],axis = 1)
#      28     list_o_shit.append(new_df)
# ---> 29     final_df = pd.concat([final_df,new_df])
#      30 final_df.columns = ['useless1','Date Relinquished','Team','useless2','Player','Injury','useless3',
#      31                    'useless4','useless5','useless6','Date Returned','Notes about Return']
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     227                        verify_integrity=verify_integrity,
#     228                        copy=copy, sort=sort)
# --> 229     return op.get_result()
#     230
#     231
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     424             new_data = concatenate_block_managers(
#     425                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 426                 copy=self.copy)
#     427             if not self.copy:
#     428                 new_data._consolidate_inplace()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2063         blocks.append(b)
#    2064
# -> 2065     return BlockManager(blocks, axes)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     112
#     113         if do_integrity_check:
# --> 114             self._verify_integrity()
#     115
#     116         self._consolidate_check()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     314                                  'block items\n# manager items: {0}, # '
#     315                                  'tot_items: {1}'.format(
# --> 316                                      len(self.items), tot_items))
#     317
#     318     def apply(self, f, axes=None, filter=None, do_integrity_check=False,
#
# AssertionError: Number of manager items must equal union of block items
# # manager items: 10, # tot_items: 13

# %%
final_df.head()
# Out:
#    index  Unnamed: 0       Date     Team Acquired  Relinquished  \
# 0      0           0 2000-03-23  Rockies      NaN  John Thomson
# 1    290         290 2001-05-25  Rockies      NaN  John Thomson
#
#                                                Notes        person  \
# 0  placed on 60-day DL recovering from surgery on...  John Thomson
# 1                                placed on 15-day DL  John Thomson
#
#    order stuff  index       Date              Notes
# 0            1  234.0 2001-05-12  activated from DL
# 1            1    NaN        NaT                NaN

# %%
final_df['duration of injury'] = final_df['Date Returned']-final_df['Date Relinquished']
final_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'Date Returned'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-9fca12c032f7> in <module>
# ----> 1 final_df['duration of injury'] = final_df['Date Returned']-final_df['Date Relinquished']
#       2 final_df.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'Date Returned'

# %%
final_df['duration of injury'].iloc[1].days
# Out:
# 3

# %%
def temp(x):
    return x.days
final_df['duration of injury integer'] = final_df['duration of injury'].apply(temp)

# %%
final_df.head()
# Out:
#   Date Relinquished       Team       Player                         Injury  \
# 0        2018-08-09    Dodgers  Yasiel Puig           oblique injury (DTD)
# 1        2019-05-21       Reds  Yasiel Puig  sprained right shoulder (DTD)
# 0        2018-09-30    Indians    Yan Gomes       right thumb injury (DTD)
# 1        2019-05-07  Nationals    Yan Gomes          bruised forearm (DTD)
# 0        2018-08-07       Reds   Joey Votto              knee injury (DTD)
#
#   Date Returned  Notes about Return duration of injury  \
# 0           NaT                 NaN                NaT
# 1    2019-05-24  returned to lineup             3 days
# 0    2018-10-05  returned to lineup             5 days
# 1    2019-05-08  returned to lineup             1 days
# 0    2018-08-10  returned to lineup             3 days
#
#    duration of injury integer
# 0                         NaN
# 1                         3.0
# 0                         5.0
# 1                         1.0
# 0                         3.0

# %%
final_df[final_df['duration of injury integer']==302]
# Out:
#   Date Relinquished       Team         Player                       Injury  \
# 1        2018-09-07  Cardinals  Yadier Molina  left hamstring injury (DTD)
#
#   Date Returned  Notes about Return duration of injury  \
# 1    2019-07-06  returned to lineup           302 days
#
#    duration of injury integer
# 1                       302.0

# %%
final_df[final_df['Player'] == 'Yadier Molina']
# Out:
#   Date Relinquished       Team         Player                       Injury  \
# 0        2018-09-07  Cardinals  Yadier Molina  left hamstring injury (DTD)
# 1        2019-05-29  Cardinals  Yadier Molina     bruised right hand (DTD)
# 2        2019-07-04  Cardinals  Yadier Molina     right thumb injury (DTD)
# 3        2019-07-07  Cardinals  Yadier Molina     right thumb injury (DTD)
#
#   Date Returned  Notes about Return duration of injury
# 0           NaT                 NaN                NaT
# 1    2018-09-13  returned to lineup          -258 days
# 2    2019-07-06  returned to lineup             2 days
# 3           NaT                 NaN                NaT

# %%
no_dots_df_copy[no_dots_df_copy['person']=='Yadier Molina']
# Out:
#           Date       Team       Acquired   Relinquished  \
# 352 2018-09-07  Cardinals            NaN  Yadier Molina
# 353 2018-09-13  Cardinals  Yadier Molina            NaN
# 354 2019-05-29  Cardinals            NaN  Yadier Molina
# 355 2019-07-04  Cardinals            NaN  Yadier Molina
# 356 2019-07-06  Cardinals  Yadier Molina            NaN
# 357 2019-07-07  Cardinals            NaN  Yadier Molina
#
#                            Notes         person  number_rows
# 352  left hamstring injury (DTD)  Yadier Molina            6
# 353           returned to lineup  Yadier Molina            6
# 354     bruised right hand (DTD)  Yadier Molina            6
# 355     right thumb injury (DTD)  Yadier Molina            6
# 356           returned to lineup  Yadier Molina            6
# 357     right thumb injury (DTD)  Yadier Molina            6

# %%
final_df['duration of injury'].value_counts()
# Out:
# 1 days      168
# 2 days      121
# 3 days       72
# 4 days       32
# 5 days       25
# 8 days        9
# 6 days        8
# 7 days        6
# 9 days        4
# 0 days        4
# 13 days       3
# 10 days       3
# 11 days       2
# 14 days       2
# 302 days      1
# 241 days      1
# 213 days      1
# 17 days       1
# 344 days      1
# 199 days      1
# 41 days       1
# 18 days       1
# 91 days       1
# 12 days       1
# 271 days      1
# 239 days      1
# Name: duration of injury, dtype: int64

# %%
test = no_dots_df_copy[((no_dots_df_copy['Acquired']=='Yadier Molina') | (no_dots_df_copy['Relinquished']=='Yadier Molina'))]
test.head()
# Out:
#           Date       Team       Acquired   Relinquished  \
# 352 2018-09-07  Cardinals            NaN  Yadier Molina
# 353 2018-09-13  Cardinals  Yadier Molina            NaN
# 354 2019-05-29  Cardinals            NaN  Yadier Molina
# 355 2019-07-04  Cardinals            NaN  Yadier Molina
# 356 2019-07-06  Cardinals  Yadier Molina            NaN
#
#                            Notes         person  number_rows
# 352  left hamstring injury (DTD)  Yadier Molina            6
# 353           returned to lineup  Yadier Molina            6
# 354     bruised right hand (DTD)  Yadier Molina            6
# 355     right thumb injury (DTD)  Yadier Molina            6
# 356           returned to lineup  Yadier Molina            6

# %%
def is_relinquished(x):
    if x == x: 
        return 0 
    else: 
        return 1
test['order stuff'] = test['Acquired'].apply(is_relinquished)
index_stuff = list(test['order stuff'])
list_fuckups = []
for i in range(len(index_stuff)-1):
    if index_stuff[i] == index_stuff[i+1]:
        list_fuckups.append((i+(i+1))/2)
list_fuckups
# Out:
# [2.5]

# %%
for i in list_fuckups: 
    line = pd.DataFrame({"Date": np.nan, "Team": np.nan,'Acquired':np.nan, 'Relinquished':np.nan,
                        'Notes': np.nan, 'person':np.nan, 'number_rows': np.nan,'order stuff':(i-.5)%2}, index=[i])
    test = test.reset_index().append(line, ignore_index=False)
    test = test.sort_index().reset_index(drop=True)
test
# Out:
#         Acquired                 Date                        Notes  \
# 0            NaN  2018-09-07 00:00:00  left hamstring injury (DTD)
# 1  Yadier Molina  2018-09-13 00:00:00           returned to lineup
# 2            NaN  2019-05-29 00:00:00     bruised right hand (DTD)
# 3            NaN                  NaN                          NaN
# 4            NaN  2019-07-04 00:00:00     right thumb injury (DTD)
# 5  Yadier Molina  2019-07-06 00:00:00           returned to lineup
# 6            NaN  2019-07-07 00:00:00     right thumb injury (DTD)
#
#     Relinquished       Team  index  number_rows  order stuff         person
# 0  Yadier Molina  Cardinals  352.0          6.0          1.0  Yadier Molina
# 1            NaN  Cardinals  353.0          6.0          0.0  Yadier Molina
# 2  Yadier Molina  Cardinals  354.0          6.0          1.0  Yadier Molina
# 3            NaN        NaN    NaN          NaN          0.0            NaN
# 4  Yadier Molina  Cardinals  355.0          6.0          1.0  Yadier Molina
# 5            NaN  Cardinals  356.0          6.0          0.0  Yadier Molina
# 6  Yadier Molina  Cardinals  357.0          6.0          1.0  Yadier Molina

# %%
left = test[test['order stuff'] == 1.0].reset_index()

# %%
right = test[test['order stuff'] == 0][['Date','Notes']].reset_index()

# %%
right
# Out:
#    index       Date               Notes
# 0      0 2018-08-07  returned to lineup
# 1      2        NaT                 NaN
# 2      4 2019-05-24  returned to lineup

# %%
pd.concat([left,right],axis = 1)
# Out:
#    index       Date     Team Acquired Relinquished  \
# 0    1.0 2018-08-09  Dodgers      NaN  Yasiel Puig
# 1    3.0 2019-05-21     Reds      NaN  Yasiel Puig
# 2    NaN        NaT      NaN      NaN          NaN
#
#                            Notes       person  number_rows  order stuff  \
# 0           oblique injury (DTD)  Yasiel Puig          4.0          1.0
# 1  sprained right shoulder (DTD)  Yasiel Puig          4.0          1.0
# 2                            NaN          NaN          NaN          NaN
#
#    index       Date               Notes
# 0      0 2018-08-07  returned to lineup
# 1      2        NaT                 NaN
# 2      4 2019-05-24  returned to lineup

# %%
filler = pd.DataFrame(no_dots_df_copy['person'].value_counts()).reset_index()
filler
# Out:
#                               index  person
# 0                      Niko Goodrum      12
# 1                       Khris Davis      11
# 2                       Kris Bryant      10
# 3                 Andrew Benintendi      10
# 4                   Kevin Kiermaier      10
# 5                      Yoan Moncada      10
# 6                  Brandon Crawford      10
# 7                        Dee Gordon      10
# 8                        Tommy Pham      10
# 9                    Avisail Garcia      10
# 10                     Jorge Alfaro      10
# 11             Tim Anderson (Devon)       8
# 12                Edwin Encarnacion       8
# 13                   Gleyber Torres       8
# 14                  Ryan Braun (J.)       8
# 15                        Jay Bruce       8
# 16                 Asdrubal Cabrera       8
# 17                       Matt Adams       8
# 18                Andrelton Simmons       7
# 19                    Hunter Dozier       7
# 20                       Mike Trout       7
# 21                 Christian Yelich       7
# 22                     Tyler Naquin       7
# 23                      Jean Segura       7
# 24                    Eduardo Núñez       7
# 25   Julio Martinez / J.D. Martinez       7
# 26                      Nick Senzel       6
# 27                  George Springer       6
# 28                    Albert Pujols       6
# 29                Chris Davis (Lyn)       6
# ..                              ...     ...
# 331                 Tucker Barnhart       1
# 332                      Luis Urias       1
# 333                   Michael Perez       1
# 334                   Austin Slater       1
# 335             Jose Abreu (Dariel)       1
# 336                    Adam Haseley       1
# 337                   Jose Alvarado       1
# 338                  Russell Martin       1
# 339                     Zack Cozart       1
# 340                  Richard Bleier       1
# 341             Austin Bibens-Dirkx       1
# 342                 Tyler Thornburg       1
# 343                     Curt Casali       1
# 344               knee injury (DTD)       1
# 345                      Chris Sale       1
# 346               Francisco Liriano       1
# 347                    Jacob deGrom       1
# 348                   Steven Wright       1
# 349                       Juan Soto       1
# 350        Ryan Zimmerman (Wallace)       1
# 351                    Wade LeBlanc       1
# 352                   Brett Kennedy       1
# 353                     Steven Matz       1
# 354                      Keone Kela       1
# 355               Jeremy Hellickson       1
# 356                      Matt Beaty       1
# 357              Fernando Tatis Jr.       1
# 358                   Justin Shafer       1
# 359               Willson Contreras       1
# 360                    Wilson Ramos       1
#
# [361 rows x 2 columns]

# %%
no_dots_df_copy = no_dots_df_copy.merge(filler, left_on='person',right_on='index', copy = False)[
    ['Date','Team','Acquired','Relinquished','Notes','person_x','person_y']]
no_dots_df_copy.columns = ['Date','Team','Acquired','Relinquished','Notes','person','number_rows']
no_dots_df_copy.head()
# Out:
#         Date     Team     Acquired Relinquished  \
# 0 2018-08-07  Dodgers  Yasiel Puig          NaN
# 1 2018-08-09  Dodgers          NaN  Yasiel Puig
# 2 2019-05-21     Reds          NaN  Yasiel Puig
# 3 2019-05-24     Reds  Yasiel Puig          NaN
# 4 2018-08-07  Indians    Yan Gomes          NaN
#
#                            Notes       person  number_rows
# 0             returned to lineup  Yasiel Puig            4
# 1           oblique injury (DTD)  Yasiel Puig            4
# 2  sprained right shoulder (DTD)  Yasiel Puig            4
# 3             returned to lineup  Yasiel Puig            4
# 4             returned to lineup    Yan Gomes            5

# %%
cleanest_rows = no_dots_df_copy[no_dots_df_copy['number_rows']==2]
cleanest_rows = cleanest_rows.dropna(subset=['Relinquished']).merge(cleanest_rows,left_on='Relinquished',right_on='Acquired')
cleanest_rows = cleanest_rows[['Date_x','Team_x','Relinquished_x','Notes_x','Date_y','Notes_y']]
cleanest_rows.columns = ['date injured','team','player','notes on injury','date returned','notes on return']
cleanest_rows = cleanest_rows.drop(cleanest_rows[cleanest_rows['date injured']>cleanest_rows['date returned']].index)
cleanest_rows.head()

# %%
cleanest_rows['number of days injured'] = cleanest_rows['date returned']-cleanest_rows['date injured']
cleanest_rows.head()

# %%
#extraneous_row = cleanest_rows[cleanest_rows['date injured']>cleanest_rows['date returned']]
#extraneous_row['date return']

# %%
cleanest_rows['notes on injury'].unique()

# %%
cleanest_rows.groupby('notes on injury')['number of days injured'].describe()

# %%
with open('untitled.txt') as f:
    content = f.readlines()

# %%
content = [x.strip() for x in content] 
label = [x.split()[0][:-1] for x in content]
description = [x.split(' ',1)[1:][0] for x in content]

# %%
pd.set_option('max_colwidth',1000)
pd.DataFrame({'label':label,'Description':description})
# Out:
#        label  \
# 0   playerID
# 1     yearID
# 2      Stint
# 3     teamID
# 4       lgID
# 5          G
# 6         AB
# 7          R
# 8          H
# 9         2B
# 10        3B
# 11        HR
# 12       RBI
# 13        SB
# 14        CS
# 15        BB
# 16        SO
# 17       IBB
# 18       HBP
# 19        SH
# 20        SF
# 21      GIDP
#
#                                                                                                                                      Description
# 0                                                                                                                                 Player ID code
# 1                                                                                               Year - the season in which the player was active
# 2                                                                                          player's stint (order of appearances within a season)
# 3                                                                                                                      Team - team player was in
# 4                                                                                                                                         League
# 5                                                                                                                 Games - number of games played
# 6                                                                                                                    At Bats - number of at-bats
# 7                                                                                          Runs - number of runs or scores player contributed to
# 8                                                                             Hits - contact with the ball results in player reaching first base
# 9                                                                             Doubles - contact with ball results in player reaching second base
# 10                                                                             Triples - contact with ball results in player reaching third base
# 11                                                                                                                                      Homeruns
# 12                                                                                                                                Runs Batted In
# 13                                                                                                                                  Stolen Bases
# 14                                                                                                                               Caught Stealing
# 15                                                                   Base on Balls - 4 calls that result in balls = immediate walk to first base
# 16                                                                                                            Strikeouts - 3 strikes = strikeout
# 17                                                                                                                             Intentional walks
# 18                                                                                        Hit by pitch - results in immediate walk to first base
# 19  Sacrifice hits - player at the plate makes contact with the ball, is predominantly thrown out, but allows another player to advance or score
# 20                                                                                                   Sacrifice flies - similar to Sacrifice hits
# 21                                          Grounded into double plays - contact with ball results in players being out on second and first base
